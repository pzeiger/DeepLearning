# %% [markdown]
# # Content with notebooks
#
# You can also create content with Jupyter Notebooks. This means that you can include
# code blocks and their outputs in your book.
#
# ## Markdown + notebooks
#
# As it is markdown, you can embed images, HTML, etc into your posts!
#
# ![](https://myst-parser.readthedocs.io/en/latest/_static/logo-wide.svg)
#
# You can also $add_{math}$ and
#
# $$
# math^{blocks}
# $$
#
# or
#
# $$
# \begin{aligned}
# \mbox{mean} la_{tex} \\ \\
# math blocks
# \end{aligned}
# $$
#
# But make sure you \$Escape \$your \$dollar signs \$you want to keep!
#
# ## MyST markdown
#
# MyST markdown works in Jupyter Notebooks as well. For more information about MyST markdown, check
# out [the MyST guide in Jupyter Book](https://jupyterbook.org/content/myst.html),
# or see [the MyST markdown documentation](https://myst-parser.readthedocs.io/en/latest/).
#
# ## Code blocks and outputs
#
# Jupyter Book will also embed your code blocks and output in your book.
# For example, here's some sample Matplotlib code:

# %%
import numpy as np

# %%
import data
from model import MyRNNModel
import torch
from torch import nn
import time
import math

# %%
seed = 14584234
train_batch_size = 250
sequence_length = 5
p_dropout = .0
size_embedding = 50
n_hidden_layers = 50
n_rnn_layers = 1

# %%
# Set the random seed manually for reproducibility.
torch.manual_seed(seed)
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print('Using %s device' % device)
# Out:
# Using cuda device

# %%
corpus = data.Corpus('ptb_data')

def batchify(data, bsz):
    # Work out how cleanly we can divide the dataset into bsz parts.
    nbatch = data.size(0) // bsz
    # Trim off any extra elements that wouldn't cleanly fit (remainders).
    data = data.narrow(0, 0, nbatch * bsz)
    # Evenly divide the data across the bsz batches.
    data = data.view(bsz, -1).t().contiguous()
    return data.to(device)

eval_batch_size = 10
train_data = batchify(corpus.train, train_batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)

# %%
ntokens = len(corpus.dictionary)
model = MyRNNModel('RNN_TANH', ntokens, size_embedding, n_hidden_layers, n_rnn_layers, p_dropout).to(device)
criterion = nn.NLLLoss()

# %%
def repackage_hidden(h): 
    """Wraps hidden states in new Tensors, to detach them from their history."""

    if isinstance(h, torch.Tensor):
        return h.detach()
    else:
        return tuple(repackage_hidden(v) for v in h)

# %%
def get_batch(source, i):
    seq_len = min(sequence_length, len(source) - 1 - i)
    data = source[i:i+seq_len]
    target = source[i+1:i+1+seq_len].view(-1)
    return data, target


def evaluate(data_source):
    # Turn on evaluation mode which disables dropout.
    model.eval()
    total_loss = 0.
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(eval_batch_size)
    with torch.no_grad():
        for i in range(0, data_source.size(0) - 1, sequence_length):
            data, targets = get_batch(data_source, i)
            output, hidden = model(data, hidden)
            hidden = repackage_hidden(hidden)
            total_loss += len(data) * criterion(output, targets).item()
    return total_loss / (len(data_source) - 1)

# %%
def train():
    # Turn on training mode which enables dropout.
    model.train()
    total_loss = 0.
    start_time = time.time()
    ntokens = len(corpus.dictionary)
    hidden = model.init_hidden(train_batch_size)
    
    for batch, i in enumerate(range(0, train_data.size(0) - 1, sequence_length)):
        data, targets = get_batch(train_data, i)
        # Starting each batch, we detach the hidden state from how it was previously produced.
        # If we didn't, the model would try backpropagating all the way to start of the dataset.
        model.zero_grad()
        hidden = repackage_hidden(hidden)
        output, hidden = model(data, hidden)
        
        loss = criterion(output, targets)
        loss.backward()
        
        # `clip_grad_norm` helps prevent the exploding gradient problem in RNNs / LSTMs.
#        torch.nn.utils.clip_grad_norm_(model.parameters(), args.clip)
        for p in model.parameters():
            p.data.add_(p.grad, alpha=-lr)

        total_loss += loss.item()

        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | lr {:02.2f} | ms/batch {:5.2f} | '
                    'loss {:5.2f} | ppl {:8.2f}'.format(
                epoch, batch, len(train_data) // sequence_length, lr,
                elapsed * 1000 / log_interval, cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()
#        if args.dry_run:
#            break

# %%
# Loop over epochs.
lr = 2.5
n_epochs = 20
best_val_loss = None
log_interval = 1

# At any point you can hit Ctrl + C to break out of training early.
try:
    for epoch in range(1, n_epochs+1):
        epoch_start_time = time.time()
        train()
        val_loss = evaluate(val_data)
        print('-' * 89)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.2f} | '
                'valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                           val_loss, math.exp(val_loss)))
        print('-' * 89)
        # Save the model if the validation loss is the best we've seen so far.
        if not best_val_loss or val_loss < best_val_loss:
            with open('ex1_Elman.torch', 'wb') as f:
                torch.save(model, f)
            best_val_loss = val_loss
        else:
            # Anneal the learning rate if no improvement has been seen in the validation dataset.
            lr /= 4.0


except KeyboardInterrupt:
    print('-' * 89)
    print('Exiting from training early')
# Out:
# | epoch   1 |     1/  743 batches | lr 2.50 | ms/batch 332.69 | loss 18.32 | ppl 90292192.60
# | epoch   1 |     2/  743 batches | lr 2.50 | ms/batch 20.19 | loss  8.94 | ppl  7642.21
# | epoch   1 |     3/  743 batches | lr 2.50 | ms/batch 20.06 | loss  8.51 | ppl  4983.76
# | epoch   1 |     4/  743 batches | lr 2.50 | ms/batch 19.91 | loss  8.00 | ppl  2972.74
# | epoch   1 |     5/  743 batches | lr 2.50 | ms/batch 19.99 | loss  8.20 | ppl  3641.72
# | epoch   1 |     6/  743 batches | lr 2.50 | ms/batch 20.04 | loss  8.09 | ppl  3275.08
# | epoch   1 |     7/  743 batches | lr 2.50 | ms/batch 20.59 | loss  7.76 | ppl  2349.30
# | epoch   1 |     8/  743 batches | lr 2.50 | ms/batch 21.72 | loss  7.58 | ppl  1949.78
# | epoch   1 |     9/  743 batches | lr 2.50 | ms/batch 21.13 | loss  7.58 | ppl  1965.41
# | epoch   1 |    10/  743 batches | lr 2.50 | ms/batch 21.23 | loss  7.53 | ppl  1868.93
# | epoch   1 |    11/  743 batches | lr 2.50 | ms/batch 23.78 | loss  7.69 | ppl  2176.01
# | epoch   1 |    12/  743 batches | lr 2.50 | ms/batch 22.79 | loss  8.48 | ppl  4793.92
# | epoch   1 |    13/  743 batches | lr 2.50 | ms/batch 20.82 | loss  7.76 | ppl  2340.73
# | epoch   1 |    14/  743 batches | lr 2.50 | ms/batch 22.02 | loss  7.59 | ppl  1984.95
# | epoch   1 |    15/  743 batches | lr 2.50 | ms/batch 23.30 | loss  8.70 | ppl  5979.06
# | epoch   1 |    16/  743 batches | lr 2.50 | ms/batch 21.02 | loss  9.02 | ppl  8248.08
# | epoch   1 |    17/  743 batches | lr 2.50 | ms/batch 20.68 | loss  8.27 | ppl  3915.47
# | epoch   1 |    18/  743 batches | lr 2.50 | ms/batch 20.48 | loss  7.87 | ppl  2624.63
# | epoch   1 |    19/  743 batches | lr 2.50 | ms/batch 21.28 | loss 13.11 | ppl 495718.65
# | epoch   1 |    20/  743 batches | lr 2.50 | ms/batch 20.53 | loss  9.86 | ppl 19071.48
# | epoch   1 |    21/  743 batches | lr 2.50 | ms/batch 22.21 | loss 10.16 | ppl 25751.50
# | epoch   1 |    22/  743 batches | lr 2.50 | ms/batch 20.34 | loss 17.09 | ppl 26379419.81
# | epoch   1 |    23/  743 batches | lr 2.50 | ms/batch 20.26 | loss 30.60 | ppl 19547946777597.02
# | epoch   1 |    24/  743 batches | lr 2.50 | ms/batch 20.64 | loss 12.39 | ppl 239981.27
# | epoch   1 |    25/  743 batches | lr 2.50 | ms/batch 21.24 | loss 26.54 | ppl 336731915583.18
# | epoch   1 |    26/  743 batches | lr 2.50 | ms/batch 20.74 | loss 14.98 | ppl 3206932.48
# | epoch   1 |    27/  743 batches | lr 2.50 | ms/batch 20.26 | loss 24.11 | ppl 29707404766.28
# | epoch   1 |    28/  743 batches | lr 2.50 | ms/batch 20.47 | loss 14.65 | ppl 2308239.47
# | epoch   1 |    29/  743 batches | lr 2.50 | ms/batch 20.31 | loss 14.15 | ppl 1394831.19
# | epoch   1 |    30/  743 batches | lr 2.50 | ms/batch 20.35 | loss 13.12 | ppl 497322.93
# | epoch   1 |    31/  743 batches | lr 2.50 | ms/batch 21.20 | loss  9.95 | ppl 21014.81
# | epoch   1 |    32/  743 batches | lr 2.50 | ms/batch 22.40 | loss  9.83 | ppl 18655.54
# | epoch   1 |    33/  743 batches | lr 2.50 | ms/batch 21.10 | loss  9.52 | ppl 13601.82
# | epoch   1 |    34/  743 batches | lr 2.50 | ms/batch 22.81 | loss  9.85 | ppl 18925.67
# | epoch   1 |    35/  743 batches | lr 2.50 | ms/batch 21.22 | loss  9.82 | ppl 18410.42
# | epoch   1 |    36/  743 batches | lr 2.50 | ms/batch 20.73 | loss  9.44 | ppl 12565.69
# | epoch   1 |    37/  743 batches | lr 2.50 | ms/batch 22.14 | loss  9.73 | ppl 16750.56
# | epoch   1 |    38/  743 batches | lr 2.50 | ms/batch 21.18 | loss  9.30 | ppl 10959.80
# | epoch   1 |    39/  743 batches | lr 2.50 | ms/batch 21.38 | loss  9.90 | ppl 19841.84
# | epoch   1 |    40/  743 batches | lr 2.50 | ms/batch 20.50 | loss  8.91 | ppl  7379.09
# | epoch   1 |    41/  743 batches | lr 2.50 | ms/batch 20.93 | loss  9.42 | ppl 12351.64
# | epoch   1 |    42/  743 batches | lr 2.50 | ms/batch 20.29 | loss  9.11 | ppl  9009.52
# | epoch   1 |    43/  743 batches | lr 2.50 | ms/batch 19.96 | loss  9.15 | ppl  9456.02
# | epoch   1 |    44/  743 batches | lr 2.50 | ms/batch 20.01 | loss  8.92 | ppl  7469.48
# | epoch   1 |    45/  743 batches | lr 2.50 | ms/batch 19.92 | loss  9.22 | ppl 10120.66
# | epoch   1 |    46/  743 batches | lr 2.50 | ms/batch 20.41 | loss  9.30 | ppl 10981.24
# | epoch   1 |    47/  743 batches | lr 2.50 | ms/batch 20.44 | loss 13.14 | ppl 510037.03
# | epoch   1 |    48/  743 batches | lr 2.50 | ms/batch 20.43 | loss 18.76 | ppl 140898157.11
# | epoch   1 |    49/  743 batches | lr 2.50 | ms/batch 20.71 | loss 35.69 | ppl 3172046573753292.50
# | epoch   1 |    50/  743 batches | lr 2.50 | ms/batch 20.31 | loss 17.70 | ppl 48720691.76
# | epoch   1 |    51/  743 batches | lr 2.50 | ms/batch 20.26 | loss 11.66 | ppl 115864.56
# | epoch   1 |    52/  743 batches | lr 2.50 | ms/batch 22.71 | loss 12.85 | ppl 381054.43
# | epoch   1 |    53/  743 batches | lr 2.50 | ms/batch 20.96 | loss 11.19 | ppl 72127.43
# | epoch   1 |    54/  743 batches | lr 2.50 | ms/batch 20.36 | loss 10.37 | ppl 31952.52
# | epoch   1 |    55/  743 batches | lr 2.50 | ms/batch 20.69 | loss  9.66 | ppl 15740.57
# | epoch   1 |    56/  743 batches | lr 2.50 | ms/batch 22.86 | loss 11.15 | ppl 69831.87
# | epoch   1 |    57/  743 batches | lr 2.50 | ms/batch 20.14 | loss  9.75 | ppl 17076.44
# | epoch   1 |    58/  743 batches | lr 2.50 | ms/batch 20.43 | loss  9.63 | ppl 15230.46
# | epoch   1 |    59/  743 batches | lr 2.50 | ms/batch 20.46 | loss  9.55 | ppl 14024.37
# | epoch   1 |    60/  743 batches | lr 2.50 | ms/batch 20.30 | loss  9.57 | ppl 14320.24
# | epoch   1 |    61/  743 batches | lr 2.50 | ms/batch 20.25 | loss  9.44 | ppl 12571.04
# | epoch   1 |    62/  743 batches | lr 2.50 | ms/batch 21.07 | loss  9.11 | ppl  9017.76
# | epoch   1 |    63/  743 batches | lr 2.50 | ms/batch 20.61 | loss  9.40 | ppl 12049.42
# | epoch   1 |    64/  743 batches | lr 2.50 | ms/batch 20.06 | loss  9.26 | ppl 10464.33
# | epoch   1 |    65/  743 batches | lr 2.50 | ms/batch 20.33 | loss  9.14 | ppl  9343.06
# | epoch   1 |    66/  743 batches | lr 2.50 | ms/batch 20.73 | loss  9.03 | ppl  8370.52
# | epoch   1 |    67/  743 batches | lr 2.50 | ms/batch 21.54 | loss  8.90 | ppl  7366.90
# | epoch   1 |    68/  743 batches | lr 2.50 | ms/batch 22.01 | loss  9.05 | ppl  8477.09
# | epoch   1 |    69/  743 batches | lr 2.50 | ms/batch 20.72 | loss  8.93 | ppl  7559.22
# | epoch   1 |    70/  743 batches | lr 2.50 | ms/batch 20.98 | loss  8.76 | ppl  6385.85
# | epoch   1 |    71/  743 batches | lr 2.50 | ms/batch 20.76 | loss  8.68 | ppl  5873.31
# | epoch   1 |    72/  743 batches | lr 2.50 | ms/batch 22.14 | loss  8.71 | ppl  6064.36
# | epoch   1 |    73/  743 batches | lr 2.50 | ms/batch 21.41 | loss  8.51 | ppl  4983.43
# | epoch   1 |    74/  743 batches | lr 2.50 | ms/batch 22.26 | loss  8.61 | ppl  5513.03
# | epoch   1 |    75/  743 batches | lr 2.50 | ms/batch 22.96 | loss  8.29 | ppl  3987.35
# | epoch   1 |    76/  743 batches | lr 2.50 | ms/batch 20.87 | loss  8.43 | ppl  4597.39
# | epoch   1 |    77/  743 batches | lr 2.50 | ms/batch 23.56 | loss  8.32 | ppl  4119.52
# | epoch   1 |    78/  743 batches | lr 2.50 | ms/batch 20.50 | loss  8.34 | ppl  4178.63
# | epoch   1 |    79/  743 batches | lr 2.50 | ms/batch 20.30 | loss  8.20 | ppl  3632.03
# | epoch   1 |    80/  743 batches | lr 2.50 | ms/batch 21.51 | loss  8.11 | ppl  3311.10
# | epoch   1 |    81/  743 batches | lr 2.50 | ms/batch 20.64 | loss  8.12 | ppl  3362.71
# | epoch   1 |    82/  743 batches | lr 2.50 | ms/batch 20.78 | loss  7.89 | ppl  2660.59
# | epoch   1 |    83/  743 batches | lr 2.50 | ms/batch 20.97 | loss  7.74 | ppl  2301.26
# | epoch   1 |    84/  743 batches | lr 2.50 | ms/batch 20.15 | loss  7.85 | ppl  2566.35
# | epoch   1 |    85/  743 batches | lr 2.50 | ms/batch 19.86 | loss  7.75 | ppl  2332.81
# | epoch   1 |    86/  743 batches | lr 2.50 | ms/batch 19.74 | loss  7.77 | ppl  2362.07
# | epoch   1 |    87/  743 batches | lr 2.50 | ms/batch 20.10 | loss  7.68 | ppl  2161.07
# | epoch   1 |    88/  743 batches | lr 2.50 | ms/batch 20.11 | loss  7.57 | ppl  1934.56
# | epoch   1 |    89/  743 batches | lr 2.50 | ms/batch 19.88 | loss  7.74 | ppl  2300.67
# | epoch   1 |    90/  743 batches | lr 2.50 | ms/batch 19.91 | loss  7.93 | ppl  2767.14
# | epoch   1 |    91/  743 batches | lr 2.50 | ms/batch 19.64 | loss  9.52 | ppl 13630.66
# | epoch   1 |    92/  743 batches | lr 2.50 | ms/batch 19.73 | loss 13.51 | ppl 733155.87
# | epoch   1 |    93/  743 batches | lr 2.50 | ms/batch 20.29 | loss  8.25 | ppl  3811.81
# | epoch   1 |    94/  743 batches | lr 2.50 | ms/batch 20.79 | loss 10.64 | ppl 41593.46
# | epoch   1 |    95/  743 batches | lr 2.50 | ms/batch 20.05 | loss  8.00 | ppl  2991.05
# | epoch   1 |    96/  743 batches | lr 2.50 | ms/batch 19.92 | loss  8.30 | ppl  4017.05
# | epoch   1 |    97/  743 batches | lr 2.50 | ms/batch 19.81 | loss  8.07 | ppl  3210.38
# | epoch   1 |    98/  743 batches | lr 2.50 | ms/batch 19.69 | loss  8.32 | ppl  4114.10
# | epoch   1 |    99/  743 batches | lr 2.50 | ms/batch 19.96 | loss  9.55 | ppl 14027.20
# | epoch   1 |   100/  743 batches | lr 2.50 | ms/batch 19.88 | loss 11.69 | ppl 119214.73
# | epoch   1 |   101/  743 batches | lr 2.50 | ms/batch 20.02 | loss  8.80 | ppl  6644.55
# | epoch   1 |   102/  743 batches | lr 2.50 | ms/batch 20.10 | loss  9.15 | ppl  9458.58
# | epoch   1 |   103/  743 batches | lr 2.50 | ms/batch 19.96 | loss  8.72 | ppl  6099.79
# | epoch   1 |   104/  743 batches | lr 2.50 | ms/batch 20.40 | loss  8.76 | ppl  6386.87
# | epoch   1 |   105/  743 batches | lr 2.50 | ms/batch 20.23 | loss  8.65 | ppl  5715.51
# | epoch   1 |   106/  743 batches | lr 2.50 | ms/batch 19.79 | loss  8.45 | ppl  4664.00
# | epoch   1 |   107/  743 batches | lr 2.50 | ms/batch 20.18 | loss  8.35 | ppl  4233.94
# | epoch   1 |   108/  743 batches | lr 2.50 | ms/batch 20.25 | loss  8.26 | ppl  3858.95
# | epoch   1 |   109/  743 batches | lr 2.50 | ms/batch 20.12 | loss  8.25 | ppl  3833.98
# | epoch   1 |   110/  743 batches | lr 2.50 | ms/batch 20.40 | loss  8.16 | ppl  3494.08
# | epoch   1 |   111/  743 batches | lr 2.50 | ms/batch 20.15 | loss  8.08 | ppl  3238.28
# | epoch   1 |   112/  743 batches | lr 2.50 | ms/batch 20.17 | loss  7.91 | ppl  2723.52
# | epoch   1 |   113/  743 batches | lr 2.50 | ms/batch 20.26 | loss  7.92 | ppl  2759.83
# | epoch   1 |   114/  743 batches | lr 2.50 | ms/batch 20.42 | loss  7.75 | ppl  2323.25
# | epoch   1 |   115/  743 batches | lr 2.50 | ms/batch 25.83 | loss  7.80 | ppl  2433.60
# | epoch   1 |   116/  743 batches | lr 2.50 | ms/batch 20.64 | loss  7.99 | ppl  2956.07
# | epoch   1 |   117/  743 batches | lr 2.50 | ms/batch 20.38 | loss  7.86 | ppl  2595.40
# | epoch   1 |   118/  743 batches | lr 2.50 | ms/batch 20.04 | loss  7.73 | ppl  2275.33
# | epoch   1 |   119/  743 batches | lr 2.50 | ms/batch 19.72 | loss  7.74 | ppl  2302.99
# | epoch   1 |   120/  743 batches | lr 2.50 | ms/batch 19.85 | loss  7.76 | ppl  2356.57
# | epoch   1 |   121/  743 batches | lr 2.50 | ms/batch 20.54 | loss  7.54 | ppl  1875.78
# | epoch   1 |   122/  743 batches | lr 2.50 | ms/batch 20.59 | loss  7.59 | ppl  1980.96
# | epoch   1 |   123/  743 batches | lr 2.50 | ms/batch 20.63 | loss  7.63 | ppl  2055.77
# | epoch   1 |   124/  743 batches | lr 2.50 | ms/batch 20.90 | loss  7.63 | ppl  2058.03
# | epoch   1 |   125/  743 batches | lr 2.50 | ms/batch 19.98 | loss  7.76 | ppl  2341.96
# | epoch   1 |   126/  743 batches | lr 2.50 | ms/batch 21.49 | loss  9.12 | ppl  9147.83
# | epoch   1 |   127/  743 batches | lr 2.50 | ms/batch 20.99 | loss  9.25 | ppl 10387.11
# | epoch   1 |   128/  743 batches | lr 2.50 | ms/batch 21.14 | loss  8.41 | ppl  4487.15
# | epoch   1 |   129/  743 batches | lr 2.50 | ms/batch 20.36 | loss  9.13 | ppl  9217.36
# | epoch   1 |   130/  743 batches | lr 2.50 | ms/batch 20.14 | loss  9.04 | ppl  8426.07
# | epoch   1 |   131/  743 batches | lr 2.50 | ms/batch 20.11 | loss  9.50 | ppl 13297.95
# | epoch   1 |   132/  743 batches | lr 2.50 | ms/batch 19.98 | loss  8.34 | ppl  4190.05
# | epoch   1 |   133/  743 batches | lr 2.50 | ms/batch 20.00 | loss  7.99 | ppl  2953.62
# | epoch   1 |   134/  743 batches | lr 2.50 | ms/batch 20.13 | loss  8.00 | ppl  2988.83
# | epoch   1 |   135/  743 batches | lr 2.50 | ms/batch 20.16 | loss  8.10 | ppl  3291.22
# | epoch   1 |   136/  743 batches | lr 2.50 | ms/batch 20.05 | loss  7.91 | ppl  2713.32
# | epoch   1 |   137/  743 batches | lr 2.50 | ms/batch 20.62 | loss  7.83 | ppl  2503.38
# | epoch   1 |   138/  743 batches | lr 2.50 | ms/batch 20.28 | loss  7.65 | ppl  2100.38
# | epoch   1 |   139/  743 batches | lr 2.50 | ms/batch 19.70 | loss  7.56 | ppl  1916.58
# | epoch   1 |   140/  743 batches | lr 2.50 | ms/batch 19.72 | loss  7.76 | ppl  2341.87
# | epoch   1 |   141/  743 batches | lr 2.50 | ms/batch 19.77 | loss  7.69 | ppl  2182.03
# | epoch   1 |   142/  743 batches | lr 2.50 | ms/batch 20.14 | loss  9.10 | ppl  8914.51
# | epoch   1 |   143/  743 batches | lr 2.50 | ms/batch 20.16 | loss 10.41 | ppl 33244.67
# | epoch   1 |   144/  743 batches | lr 2.50 | ms/batch 19.93 | loss  8.24 | ppl  3808.38
# | epoch   1 |   145/  743 batches | lr 2.50 | ms/batch 19.70 | loss  9.28 | ppl 10767.58
# | epoch   1 |   146/  743 batches | lr 2.50 | ms/batch 19.76 | loss 12.37 | ppl 236582.22
# | epoch   1 |   147/  743 batches | lr 2.50 | ms/batch 20.33 | loss  8.96 | ppl  7749.48
# | epoch   1 |   148/  743 batches | lr 2.50 | ms/batch 20.66 | loss  8.09 | ppl  3270.14
# | epoch   1 |   149/  743 batches | lr 2.50 | ms/batch 20.48 | loss  8.58 | ppl  5311.31
# | epoch   1 |   150/  743 batches | lr 2.50 | ms/batch 20.00 | loss 10.84 | ppl 51080.34
# | epoch   1 |   151/  743 batches | lr 2.50 | ms/batch 19.97 | loss 12.58 | ppl 291329.32
# | epoch   1 |   152/  743 batches | lr 2.50 | ms/batch 19.78 | loss  8.92 | ppl  7460.53
# | epoch   1 |   153/  743 batches | lr 2.50 | ms/batch 19.99 | loss  8.72 | ppl  6141.21
# | epoch   1 |   154/  743 batches | lr 2.50 | ms/batch 19.76 | loss  8.48 | ppl  4825.72
# | epoch   1 |   155/  743 batches | lr 2.50 | ms/batch 20.14 | loss  8.23 | ppl  3766.95
# | epoch   1 |   156/  743 batches | lr 2.50 | ms/batch 20.08 | loss  8.29 | ppl  3990.72
# | epoch   1 |   157/  743 batches | lr 2.50 | ms/batch 20.02 | loss  8.64 | ppl  5660.54
# | epoch   1 |   158/  743 batches | lr 2.50 | ms/batch 20.06 | loss 12.09 | ppl 177406.30
# | epoch   1 |   159/  743 batches | lr 2.50 | ms/batch 20.51 | loss  8.83 | ppl  6810.50
# | epoch   1 |   160/  743 batches | lr 2.50 | ms/batch 20.19 | loss  8.76 | ppl  6363.39
# | epoch   1 |   161/  743 batches | lr 2.50 | ms/batch 19.87 | loss  8.83 | ppl  6834.42
# | epoch   1 |   162/  743 batches | lr 2.50 | ms/batch 20.07 | loss  8.51 | ppl  4971.50
# | epoch   1 |   163/  743 batches | lr 2.50 | ms/batch 20.36 | loss  8.33 | ppl  4140.54
# | epoch   1 |   164/  743 batches | lr 2.50 | ms/batch 19.78 | loss  8.18 | ppl  3565.28
# | epoch   1 |   165/  743 batches | lr 2.50 | ms/batch 20.18 | loss  8.10 | ppl  3298.09
# | epoch   1 |   166/  743 batches | lr 2.50 | ms/batch 19.99 | loss  7.87 | ppl  2624.81
# | epoch   1 |   167/  743 batches | lr 2.50 | ms/batch 20.36 | loss  7.79 | ppl  2420.29
# | epoch   1 |   168/  743 batches | lr 2.50 | ms/batch 22.82 | loss  7.87 | ppl  2625.53
# | epoch   1 |   169/  743 batches | lr 2.50 | ms/batch 23.52 | loss  7.78 | ppl  2394.13
# | epoch   1 |   170/  743 batches | lr 2.50 | ms/batch 21.67 | loss  7.38 | ppl  1601.63
# | epoch   1 |   171/  743 batches | lr 2.50 | ms/batch 25.53 | loss  7.48 | ppl  1776.03
# | epoch   1 |   172/  743 batches | lr 2.50 | ms/batch 20.36 | loss  7.47 | ppl  1753.86
# | epoch   1 |   173/  743 batches | lr 2.50 | ms/batch 22.43 | loss  7.37 | ppl  1593.62
# | epoch   1 |   174/  743 batches | lr 2.50 | ms/batch 21.40 | loss  7.25 | ppl  1404.52
# | epoch   1 |   175/  743 batches | lr 2.50 | ms/batch 20.55 | loss  7.51 | ppl  1830.29
# | epoch   1 |   176/  743 batches | lr 2.50 | ms/batch 20.37 | loss  7.55 | ppl  1897.63
# | epoch   1 |   177/  743 batches | lr 2.50 | ms/batch 21.22 | loss  7.32 | ppl  1511.80
# | epoch   1 |   178/  743 batches | lr 2.50 | ms/batch 20.56 | loss  7.27 | ppl  1430.53
# | epoch   1 |   179/  743 batches | lr 2.50 | ms/batch 21.29 | loss  7.33 | ppl  1525.28
# | epoch   1 |   180/  743 batches | lr 2.50 | ms/batch 21.09 | loss  7.20 | ppl  1342.59
# | epoch   1 |   181/  743 batches | lr 2.50 | ms/batch 20.12 | loss  7.38 | ppl  1604.25
# | epoch   1 |   182/  743 batches | lr 2.50 | ms/batch 19.97 | loss  7.23 | ppl  1379.96
# | epoch   1 |   183/  743 batches | lr 2.50 | ms/batch 20.09 | loss  7.24 | ppl  1398.04
# | epoch   1 |   184/  743 batches | lr 2.50 | ms/batch 20.01 | loss  7.16 | ppl  1281.69
# | epoch   1 |   185/  743 batches | lr 2.50 | ms/batch 20.37 | loss  7.10 | ppl  1207.53
# | epoch   1 |   186/  743 batches | lr 2.50 | ms/batch 19.96 | loss  7.14 | ppl  1257.72
# | epoch   1 |   187/  743 batches | lr 2.50 | ms/batch 19.66 | loss  7.05 | ppl  1149.43
# | epoch   1 |   188/  743 batches | lr 2.50 | ms/batch 19.73 | loss  6.94 | ppl  1032.19
# | epoch   1 |   189/  743 batches | lr 2.50 | ms/batch 19.89 | loss  6.99 | ppl  1086.35
# | epoch   1 |   190/  743 batches | lr 2.50 | ms/batch 21.37 | loss  7.39 | ppl  1625.37
# | epoch   1 |   191/  743 batches | lr 2.50 | ms/batch 20.41 | loss  7.68 | ppl  2156.51
# | epoch   1 |   192/  743 batches | lr 2.50 | ms/batch 20.03 | loss  7.92 | ppl  2758.47
# | epoch   1 |   193/  743 batches | lr 2.50 | ms/batch 19.80 | loss  7.49 | ppl  1788.66
# | epoch   1 |   194/  743 batches | lr 2.50 | ms/batch 19.75 | loss  7.61 | ppl  2024.13
# | epoch   1 |   195/  743 batches | lr 2.50 | ms/batch 19.90 | loss  7.89 | ppl  2660.06
# | epoch   1 |   196/  743 batches | lr 2.50 | ms/batch 20.11 | loss  7.63 | ppl  2053.77
# | epoch   1 |   197/  743 batches | lr 2.50 | ms/batch 20.01 | loss  7.44 | ppl  1695.13
# | epoch   1 |   198/  743 batches | lr 2.50 | ms/batch 19.87 | loss  7.16 | ppl  1280.80
# | epoch   1 |   199/  743 batches | lr 2.50 | ms/batch 19.97 | loss  7.33 | ppl  1525.37
# | epoch   1 |   200/  743 batches | lr 2.50 | ms/batch 19.72 | loss  7.08 | ppl  1188.60
# | epoch   1 |   201/  743 batches | lr 2.50 | ms/batch 20.25 | loss  6.94 | ppl  1028.52
# | epoch   1 |   202/  743 batches | lr 2.50 | ms/batch 20.22 | loss  7.02 | ppl  1117.38
# | epoch   1 |   203/  743 batches | lr 2.50 | ms/batch 20.13 | loss  7.04 | ppl  1141.36
# | epoch   1 |   204/  743 batches | lr 2.50 | ms/batch 20.41 | loss  6.89 | ppl   978.66
# | epoch   1 |   205/  743 batches | lr 2.50 | ms/batch 19.94 | loss  6.95 | ppl  1042.49
# | epoch   1 |   206/  743 batches | lr 2.50 | ms/batch 23.22 | loss  6.90 | ppl   993.91
# | epoch   1 |   207/  743 batches | lr 2.50 | ms/batch 22.91 | loss  6.87 | ppl   958.44
# | epoch   1 |   208/  743 batches | lr 2.50 | ms/batch 20.25 | loss  7.02 | ppl  1116.87
# | epoch   1 |   209/  743 batches | lr 2.50 | ms/batch 20.87 | loss  7.12 | ppl  1235.16
# | epoch   1 |   210/  743 batches | lr 2.50 | ms/batch 21.54 | loss  7.01 | ppl  1111.13
# | epoch   1 |   211/  743 batches | lr 2.50 | ms/batch 23.38 | loss  7.04 | ppl  1138.15
# | epoch   1 |   212/  743 batches | lr 2.50 | ms/batch 21.89 | loss  6.89 | ppl   977.82
# | epoch   1 |   213/  743 batches | lr 2.50 | ms/batch 21.22 | loss  6.94 | ppl  1029.76
# | epoch   1 |   214/  743 batches | lr 2.50 | ms/batch 20.92 | loss  7.06 | ppl  1161.84
# | epoch   1 |   215/  743 batches | lr 2.50 | ms/batch 20.92 | loss  7.07 | ppl  1176.00
# | epoch   1 |   216/  743 batches | lr 2.50 | ms/batch 22.81 | loss  7.01 | ppl  1110.35
# | epoch   1 |   217/  743 batches | lr 2.50 | ms/batch 21.23 | loss  6.97 | ppl  1059.68
# | epoch   1 |   218/  743 batches | lr 2.50 | ms/batch 20.61 | loss  6.85 | ppl   939.96
# | epoch   1 |   219/  743 batches | lr 2.50 | ms/batch 21.51 | loss  7.08 | ppl  1187.16
# | epoch   1 |   220/  743 batches | lr 2.50 | ms/batch 24.11 | loss  7.09 | ppl  1205.85
# | epoch   1 |   221/  743 batches | lr 2.50 | ms/batch 20.70 | loss  7.02 | ppl  1121.71
# | epoch   1 |   222/  743 batches | lr 2.50 | ms/batch 21.74 | loss  6.82 | ppl   917.95
# | epoch   1 |   223/  743 batches | lr 2.50 | ms/batch 24.15 | loss  6.69 | ppl   805.92
# | epoch   1 |   224/  743 batches | lr 2.50 | ms/batch 22.69 | loss  7.07 | ppl  1181.36
# | epoch   1 |   225/  743 batches | lr 2.50 | ms/batch 21.80 | loss  6.79 | ppl   886.77
# | epoch   1 |   226/  743 batches | lr 2.50 | ms/batch 22.50 | loss  6.81 | ppl   905.70
# | epoch   1 |   227/  743 batches | lr 2.50 | ms/batch 22.60 | loss  6.73 | ppl   838.82
# | epoch   1 |   228/  743 batches | lr 2.50 | ms/batch 21.33 | loss  6.89 | ppl   984.25
# | epoch   1 |   229/  743 batches | lr 2.50 | ms/batch 21.77 | loss  6.81 | ppl   906.33
# | epoch   1 |   230/  743 batches | lr 2.50 | ms/batch 22.36 | loss  6.85 | ppl   945.34
# | epoch   1 |   231/  743 batches | lr 2.50 | ms/batch 23.39 | loss  6.89 | ppl   984.06
# | epoch   1 |   232/  743 batches | lr 2.50 | ms/batch 22.17 | loss  7.00 | ppl  1092.83
# | epoch   1 |   233/  743 batches | lr 2.50 | ms/batch 20.87 | loss  6.83 | ppl   926.88
# | epoch   1 |   234/  743 batches | lr 2.50 | ms/batch 20.57 | loss  6.86 | ppl   955.40
# | epoch   1 |   235/  743 batches | lr 2.50 | ms/batch 20.67 | loss  6.75 | ppl   854.45
# | epoch   1 |   236/  743 batches | lr 2.50 | ms/batch 20.29 | loss  6.86 | ppl   954.93
# | epoch   1 |   237/  743 batches | lr 2.50 | ms/batch 20.56 | loss  6.95 | ppl  1039.85
# | epoch   1 |   238/  743 batches | lr 2.50 | ms/batch 20.83 | loss  6.77 | ppl   869.81
# | epoch   1 |   239/  743 batches | lr 2.50 | ms/batch 20.04 | loss  6.97 | ppl  1065.60
# | epoch   1 |   240/  743 batches | lr 2.50 | ms/batch 20.01 | loss  6.99 | ppl  1088.52
# | epoch   1 |   241/  743 batches | lr 2.50 | ms/batch 20.56 | loss  7.11 | ppl  1222.76
# | epoch   1 |   242/  743 batches | lr 2.50 | ms/batch 22.85 | loss  6.91 | ppl  1006.26
# | epoch   1 |   243/  743 batches | lr 2.50 | ms/batch 21.11 | loss  7.18 | ppl  1317.23
# | epoch   1 |   244/  743 batches | lr 2.50 | ms/batch 22.21 | loss  7.16 | ppl  1282.81
# | epoch   1 |   245/  743 batches | lr 2.50 | ms/batch 21.31 | loss  6.99 | ppl  1089.24
# | epoch   1 |   246/  743 batches | lr 2.50 | ms/batch 24.93 | loss  7.01 | ppl  1109.15
# | epoch   1 |   247/  743 batches | lr 2.50 | ms/batch 20.76 | loss  7.04 | ppl  1142.70
# | epoch   1 |   248/  743 batches | lr 2.50 | ms/batch 21.97 | loss  6.97 | ppl  1066.38
# | epoch   1 |   249/  743 batches | lr 2.50 | ms/batch 22.39 | loss  6.87 | ppl   960.85
# | epoch   1 |   250/  743 batches | lr 2.50 | ms/batch 21.57 | loss  6.77 | ppl   874.89
# | epoch   1 |   251/  743 batches | lr 2.50 | ms/batch 24.88 | loss  6.76 | ppl   859.02
# | epoch   1 |   252/  743 batches | lr 2.50 | ms/batch 23.61 | loss  6.88 | ppl   969.16
# | epoch   1 |   253/  743 batches | lr 2.50 | ms/batch 23.61 | loss  6.84 | ppl   936.27
# | epoch   1 |   254/  743 batches | lr 2.50 | ms/batch 20.71 | loss  6.88 | ppl   973.07
# | epoch   1 |   255/  743 batches | lr 2.50 | ms/batch 20.97 | loss  7.05 | ppl  1154.97
# | epoch   1 |   256/  743 batches | lr 2.50 | ms/batch 23.21 | loss  6.84 | ppl   937.26
# | epoch   1 |   257/  743 batches | lr 2.50 | ms/batch 21.91 | loss  6.83 | ppl   925.90
# | epoch   1 |   258/  743 batches | lr 2.50 | ms/batch 20.34 | loss  6.80 | ppl   894.43
# | epoch   1 |   259/  743 batches | lr 2.50 | ms/batch 20.66 | loss  6.86 | ppl   956.25
# | epoch   1 |   260/  743 batches | lr 2.50 | ms/batch 20.52 | loss  6.95 | ppl  1040.18
# | epoch   1 |   261/  743 batches | lr 2.50 | ms/batch 20.51 | loss  6.72 | ppl   830.16
# | epoch   1 |   262/  743 batches | lr 2.50 | ms/batch 20.72 | loss  6.68 | ppl   798.79
# | epoch   1 |   263/  743 batches | lr 2.50 | ms/batch 20.09 | loss  6.80 | ppl   894.52
# | epoch   1 |   264/  743 batches | lr 2.50 | ms/batch 20.31 | loss  6.83 | ppl   924.62
# | epoch   1 |   265/  743 batches | lr 2.50 | ms/batch 20.25 | loss  6.84 | ppl   936.18
# | epoch   1 |   266/  743 batches | lr 2.50 | ms/batch 20.32 | loss  6.81 | ppl   908.36
# | epoch   1 |   267/  743 batches | lr 2.50 | ms/batch 20.09 | loss  6.77 | ppl   870.22
# | epoch   1 |   268/  743 batches | lr 2.50 | ms/batch 19.86 | loss  7.32 | ppl  1512.91
# | epoch   1 |   269/  743 batches | lr 2.50 | ms/batch 20.44 | loss  9.79 | ppl 17775.19
# | epoch   1 |   270/  743 batches | lr 2.50 | ms/batch 21.45 | loss  8.05 | ppl  3148.31
# | epoch   1 |   271/  743 batches | lr 2.50 | ms/batch 20.73 | loss  8.35 | ppl  4218.63
# | epoch   1 |   272/  743 batches | lr 2.50 | ms/batch 23.43 | loss  7.88 | ppl  2650.82
# | epoch   1 |   273/  743 batches | lr 2.50 | ms/batch 22.51 | loss  7.76 | ppl  2337.45
# | epoch   1 |   274/  743 batches | lr 2.50 | ms/batch 22.12 | loss  7.58 | ppl  1950.34
# | epoch   1 |   275/  743 batches | lr 2.50 | ms/batch 21.99 | loss  7.57 | ppl  1934.00
# | epoch   1 |   276/  743 batches | lr 2.50 | ms/batch 21.24 | loss  7.45 | ppl  1722.43
# | epoch   1 |   277/  743 batches | lr 2.50 | ms/batch 24.18 | loss  7.31 | ppl  1493.72
# | epoch   1 |   278/  743 batches | lr 2.50 | ms/batch 21.44 | loss  7.33 | ppl  1523.41
# | epoch   1 |   279/  743 batches | lr 2.50 | ms/batch 21.79 | loss  7.25 | ppl  1414.92
# | epoch   1 |   280/  743 batches | lr 2.50 | ms/batch 20.82 | loss  7.13 | ppl  1246.72
# | epoch   1 |   281/  743 batches | lr 2.50 | ms/batch 21.40 | loss  7.12 | ppl  1236.93
# | epoch   1 |   282/  743 batches | lr 2.50 | ms/batch 20.75 | loss  7.04 | ppl  1138.77
# | epoch   1 |   283/  743 batches | lr 2.50 | ms/batch 21.25 | loss  7.03 | ppl  1130.84
# | epoch   1 |   284/  743 batches | lr 2.50 | ms/batch 21.60 | loss  6.93 | ppl  1025.36
# | epoch   1 |   285/  743 batches | lr 2.50 | ms/batch 23.11 | loss  6.94 | ppl  1037.19
# | epoch   1 |   286/  743 batches | lr 2.50 | ms/batch 20.97 | loss  6.90 | ppl   997.13
# | epoch   1 |   287/  743 batches | lr 2.50 | ms/batch 20.95 | loss  6.91 | ppl  1001.37
# | epoch   1 |   288/  743 batches | lr 2.50 | ms/batch 21.25 | loss  6.84 | ppl   933.83
# | epoch   1 |   289/  743 batches | lr 2.50 | ms/batch 21.83 | loss  6.80 | ppl   895.26
# | epoch   1 |   290/  743 batches | lr 2.50 | ms/batch 22.86 | loss  6.88 | ppl   973.90
# | epoch   1 |   291/  743 batches | lr 2.50 | ms/batch 23.49 | loss  6.81 | ppl   908.04
# | epoch   1 |   292/  743 batches | lr 2.50 | ms/batch 26.43 | loss  6.75 | ppl   850.63
# | epoch   1 |   293/  743 batches | lr 2.50 | ms/batch 21.20 | loss  6.88 | ppl   975.24
# | epoch   1 |   294/  743 batches | lr 2.50 | ms/batch 22.92 | loss  6.89 | ppl   986.70
# | epoch   1 |   295/  743 batches | lr 2.50 | ms/batch 22.22 | loss  6.81 | ppl   909.14
# | epoch   1 |   296/  743 batches | lr 2.50 | ms/batch 21.50 | loss  6.90 | ppl   988.33
# | epoch   1 |   297/  743 batches | lr 2.50 | ms/batch 22.40 | loss  6.89 | ppl   977.50
# | epoch   1 |   298/  743 batches | lr 2.50 | ms/batch 20.71 | loss  7.15 | ppl  1272.01
# | epoch   1 |   299/  743 batches | lr 2.50 | ms/batch 20.44 | loss  7.02 | ppl  1121.56
# | epoch   1 |   300/  743 batches | lr 2.50 | ms/batch 20.69 | loss  6.95 | ppl  1045.59
# | epoch   1 |   301/  743 batches | lr 2.50 | ms/batch 20.98 | loss  6.82 | ppl   918.31
# | epoch   1 |   302/  743 batches | lr 2.50 | ms/batch 21.60 | loss  6.81 | ppl   906.83
# | epoch   1 |   303/  743 batches | lr 2.50 | ms/batch 22.11 | loss  6.83 | ppl   924.14
# | epoch   1 |   304/  743 batches | lr 2.50 | ms/batch 20.68 | loss  6.75 | ppl   849.97
# | epoch   1 |   305/  743 batches | lr 2.50 | ms/batch 20.75 | loss  6.80 | ppl   894.76
# | epoch   1 |   306/  743 batches | lr 2.50 | ms/batch 23.68 | loss  6.74 | ppl   849.11
# | epoch   1 |   307/  743 batches | lr 2.50 | ms/batch 20.79 | loss  6.86 | ppl   956.65
# | epoch   1 |   308/  743 batches | lr 2.50 | ms/batch 20.75 | loss  6.89 | ppl   985.26
# | epoch   1 |   309/  743 batches | lr 2.50 | ms/batch 20.49 | loss  6.73 | ppl   838.16
# | epoch   1 |   310/  743 batches | lr 2.50 | ms/batch 20.13 | loss  6.79 | ppl   885.18
# | epoch   1 |   311/  743 batches | lr 2.50 | ms/batch 19.80 | loss  6.72 | ppl   825.32
# | epoch   1 |   312/  743 batches | lr 2.50 | ms/batch 20.51 | loss  6.72 | ppl   825.38
# | epoch   1 |   313/  743 batches | lr 2.50 | ms/batch 23.58 | loss  6.75 | ppl   855.93
# | epoch   1 |   314/  743 batches | lr 2.50 | ms/batch 20.28 | loss  6.86 | ppl   950.47
# | epoch   1 |   315/  743 batches | lr 2.50 | ms/batch 20.60 | loss  7.05 | ppl  1153.08
# | epoch   1 |   316/  743 batches | lr 2.50 | ms/batch 21.75 | loss  6.89 | ppl   981.04
# | epoch   1 |   317/  743 batches | lr 2.50 | ms/batch 21.19 | loss  6.94 | ppl  1035.53
# | epoch   1 |   318/  743 batches | lr 2.50 | ms/batch 21.11 | loss  6.84 | ppl   933.04
# | epoch   1 |   319/  743 batches | lr 2.50 | ms/batch 20.87 | loss  6.80 | ppl   901.58
# | epoch   1 |   320/  743 batches | lr 2.50 | ms/batch 21.06 | loss  6.91 | ppl  1001.46
# | epoch   1 |   321/  743 batches | lr 2.50 | ms/batch 20.28 | loss  6.77 | ppl   871.07
# | epoch   1 |   322/  743 batches | lr 2.50 | ms/batch 20.80 | loss  6.93 | ppl  1020.03
# | epoch   1 |   323/  743 batches | lr 2.50 | ms/batch 21.20 | loss  6.83 | ppl   923.04
# | epoch   1 |   324/  743 batches | lr 2.50 | ms/batch 21.00 | loss  6.77 | ppl   867.21
# | epoch   1 |   325/  743 batches | lr 2.50 | ms/batch 20.46 | loss  6.65 | ppl   774.85
# | epoch   1 |   326/  743 batches | lr 2.50 | ms/batch 20.41 | loss  6.72 | ppl   832.14
# | epoch   1 |   327/  743 batches | lr 2.50 | ms/batch 20.51 | loss  6.71 | ppl   823.58
# | epoch   1 |   328/  743 batches | lr 2.50 | ms/batch 20.37 | loss  6.83 | ppl   925.30
# | epoch   1 |   329/  743 batches | lr 2.50 | ms/batch 20.69 | loss  6.85 | ppl   943.20
# | epoch   1 |   330/  743 batches | lr 2.50 | ms/batch 20.49 | loss  6.89 | ppl   983.94
# | epoch   1 |   331/  743 batches | lr 2.50 | ms/batch 20.65 | loss  6.93 | ppl  1017.64
# | epoch   1 |   332/  743 batches | lr 2.50 | ms/batch 21.35 | loss  6.94 | ppl  1034.81
# | epoch   1 |   333/  743 batches | lr 2.50 | ms/batch 21.10 | loss  7.18 | ppl  1310.39
# | epoch   1 |   334/  743 batches | lr 2.50 | ms/batch 20.29 | loss  7.86 | ppl  2596.00
# | epoch   1 |   335/  743 batches | lr 2.50 | ms/batch 20.30 | loss  7.68 | ppl  2159.85
# | epoch   1 |   336/  743 batches | lr 2.50 | ms/batch 20.15 | loss  7.35 | ppl  1559.77
# | epoch   1 |   337/  743 batches | lr 2.50 | ms/batch 20.09 | loss  7.27 | ppl  1440.18
# | epoch   1 |   338/  743 batches | lr 2.50 | ms/batch 20.19 | loss  7.33 | ppl  1523.95
# | epoch   1 |   339/  743 batches | lr 2.50 | ms/batch 20.42 | loss  7.17 | ppl  1296.26
# | epoch   1 |   340/  743 batches | lr 2.50 | ms/batch 20.38 | loss  6.95 | ppl  1045.39
# | epoch   1 |   341/  743 batches | lr 2.50 | ms/batch 20.05 | loss  7.02 | ppl  1123.56
# | epoch   1 |   342/  743 batches | lr 2.50 | ms/batch 21.35 | loss  6.96 | ppl  1053.64
# | epoch   1 |   343/  743 batches | lr 2.50 | ms/batch 20.79 | loss  6.92 | ppl  1015.08
# | epoch   1 |   344/  743 batches | lr 2.50 | ms/batch 20.17 | loss  6.75 | ppl   850.14
# | epoch   1 |   345/  743 batches | lr 2.50 | ms/batch 19.88 | loss  6.89 | ppl   985.11
# | epoch   1 |   346/  743 batches | lr 2.50 | ms/batch 20.26 | loss  6.84 | ppl   931.28
# | epoch   1 |   347/  743 batches | lr 2.50 | ms/batch 20.32 | loss  6.84 | ppl   936.09
# | epoch   1 |   348/  743 batches | lr 2.50 | ms/batch 20.15 | loss  6.80 | ppl   899.23
# | epoch   1 |   349/  743 batches | lr 2.50 | ms/batch 20.39 | loss  6.88 | ppl   975.13
# | epoch   1 |   350/  743 batches | lr 2.50 | ms/batch 21.03 | loss  6.68 | ppl   798.19
# | epoch   1 |   351/  743 batches | lr 2.50 | ms/batch 20.49 | loss  6.72 | ppl   826.69
# | epoch   1 |   352/  743 batches | lr 2.50 | ms/batch 20.34 | loss  6.87 | ppl   967.52
# | epoch   1 |   353/  743 batches | lr 2.50 | ms/batch 20.32 | loss  6.89 | ppl   983.88
# | epoch   1 |   354/  743 batches | lr 2.50 | ms/batch 21.24 | loss  6.85 | ppl   947.47
# | epoch   1 |   355/  743 batches | lr 2.50 | ms/batch 20.60 | loss  6.85 | ppl   940.44
# | epoch   1 |   356/  743 batches | lr 2.50 | ms/batch 20.70 | loss  6.85 | ppl   945.06
# | epoch   1 |   357/  743 batches | lr 2.50 | ms/batch 20.16 | loss  6.63 | ppl   757.56
# | epoch   1 |   358/  743 batches | lr 2.50 | ms/batch 20.33 | loss  6.80 | ppl   895.80
# | epoch   1 |   359/  743 batches | lr 2.50 | ms/batch 20.27 | loss  6.70 | ppl   814.87
# | epoch   1 |   360/  743 batches | lr 2.50 | ms/batch 20.34 | loss  6.72 | ppl   826.25
# | epoch   1 |   361/  743 batches | lr 2.50 | ms/batch 20.35 | loss  6.60 | ppl   734.03
# | epoch   1 |   362/  743 batches | lr 2.50 | ms/batch 20.62 | loss  6.79 | ppl   889.36
# | epoch   1 |   363/  743 batches | lr 2.50 | ms/batch 21.49 | loss  6.71 | ppl   819.33
# | epoch   1 |   364/  743 batches | lr 2.50 | ms/batch 21.27 | loss  6.95 | ppl  1043.10
# | epoch   1 |   365/  743 batches | lr 2.50 | ms/batch 21.07 | loss  7.43 | ppl  1693.35
# | epoch   1 |   366/  743 batches | lr 2.50 | ms/batch 20.39 | loss  7.95 | ppl  2837.28
# | epoch   1 |   367/  743 batches | lr 2.50 | ms/batch 20.49 | loss  7.31 | ppl  1493.01
# | epoch   1 |   368/  743 batches | lr 2.50 | ms/batch 20.58 | loss  7.42 | ppl  1668.46
# | epoch   1 |   369/  743 batches | lr 2.50 | ms/batch 20.62 | loss  7.22 | ppl  1364.19
# | epoch   1 |   370/  743 batches | lr 2.50 | ms/batch 20.49 | loss  7.20 | ppl  1344.47
# | epoch   1 |   371/  743 batches | lr 2.50 | ms/batch 20.87 | loss  7.18 | ppl  1310.96
# | epoch   1 |   372/  743 batches | lr 2.50 | ms/batch 21.36 | loss  7.10 | ppl  1207.75
# | epoch   1 |   373/  743 batches | lr 2.50 | ms/batch 21.11 | loss  7.12 | ppl  1230.90
# | epoch   1 |   374/  743 batches | lr 2.50 | ms/batch 22.01 | loss  7.06 | ppl  1168.54
# | epoch   1 |   375/  743 batches | lr 2.50 | ms/batch 23.80 | loss  7.03 | ppl  1129.32
# | epoch   1 |   376/  743 batches | lr 2.50 | ms/batch 21.19 | loss  7.10 | ppl  1214.62
# | epoch   1 |   377/  743 batches | lr 2.50 | ms/batch 21.14 | loss  6.89 | ppl   982.58
# | epoch   1 |   378/  743 batches | lr 2.50 | ms/batch 21.04 | loss  6.92 | ppl  1007.84
# | epoch   1 |   379/  743 batches | lr 2.50 | ms/batch 20.92 | loss  6.73 | ppl   838.99
# | epoch   1 |   380/  743 batches | lr 2.50 | ms/batch 20.67 | loss  6.84 | ppl   938.54
# | epoch   1 |   381/  743 batches | lr 2.50 | ms/batch 20.54 | loss  6.81 | ppl   908.21
# | epoch   1 |   382/  743 batches | lr 2.50 | ms/batch 21.18 | loss  6.69 | ppl   804.72
# | epoch   1 |   383/  743 batches | lr 2.50 | ms/batch 20.63 | loss  6.84 | ppl   936.73
# | epoch   1 |   384/  743 batches | lr 2.50 | ms/batch 21.95 | loss  6.76 | ppl   862.58
# | epoch   1 |   385/  743 batches | lr 2.50 | ms/batch 21.78 | loss  6.74 | ppl   848.22
# | epoch   1 |   386/  743 batches | lr 2.50 | ms/batch 20.58 | loss  6.68 | ppl   800.15
# | epoch   1 |   387/  743 batches | lr 2.50 | ms/batch 21.18 | loss  6.74 | ppl   842.55
# | epoch   1 |   388/  743 batches | lr 2.50 | ms/batch 21.37 | loss  6.67 | ppl   791.13
# | epoch   1 |   389/  743 batches | lr 2.50 | ms/batch 21.44 | loss  6.72 | ppl   825.68
# | epoch   1 |   390/  743 batches | lr 2.50 | ms/batch 20.90 | loss  6.79 | ppl   888.14
# | epoch   1 |   391/  743 batches | lr 2.50 | ms/batch 20.82 | loss  6.74 | ppl   847.34
# | epoch   1 |   392/  743 batches | lr 2.50 | ms/batch 20.77 | loss  6.72 | ppl   831.08
# | epoch   1 |   393/  743 batches | lr 2.50 | ms/batch 21.53 | loss  6.77 | ppl   870.33
# | epoch   1 |   394/  743 batches | lr 2.50 | ms/batch 23.17 | loss  6.72 | ppl   828.83
# | epoch   1 |   395/  743 batches | lr 2.50 | ms/batch 22.00 | loss  6.80 | ppl   901.74
# | epoch   1 |   396/  743 batches | lr 2.50 | ms/batch 21.79 | loss  7.00 | ppl  1094.78
# | epoch   1 |   397/  743 batches | lr 2.50 | ms/batch 21.69 | loss  6.84 | ppl   934.80
# | epoch   1 |   398/  743 batches | lr 2.50 | ms/batch 20.85 | loss  6.97 | ppl  1062.06
# | epoch   1 |   399/  743 batches | lr 2.50 | ms/batch 20.75 | loss  6.85 | ppl   945.40
# | epoch   1 |   400/  743 batches | lr 2.50 | ms/batch 20.67 | loss  6.85 | ppl   948.32
# | epoch   1 |   401/  743 batches | lr 2.50 | ms/batch 20.43 | loss  6.68 | ppl   798.44
# | epoch   1 |   402/  743 batches | lr 2.50 | ms/batch 20.61 | loss  6.78 | ppl   878.09
# | epoch   1 |   403/  743 batches | lr 2.50 | ms/batch 20.52 | loss  6.82 | ppl   913.16
# | epoch   1 |   404/  743 batches | lr 2.50 | ms/batch 21.29 | loss  6.86 | ppl   954.71
# | epoch   1 |   405/  743 batches | lr 2.50 | ms/batch 22.28 | loss  6.72 | ppl   832.32
# | epoch   1 |   406/  743 batches | lr 2.50 | ms/batch 20.85 | loss  6.79 | ppl   893.05
# | epoch   1 |   407/  743 batches | lr 2.50 | ms/batch 20.69 | loss  6.80 | ppl   898.16
# | epoch   1 |   408/  743 batches | lr 2.50 | ms/batch 20.69 | loss  6.60 | ppl   735.78
# | epoch   1 |   409/  743 batches | lr 2.50 | ms/batch 20.64 | loss  6.70 | ppl   809.48
# | epoch   1 |   410/  743 batches | lr 2.50 | ms/batch 21.03 | loss  6.66 | ppl   783.75
# | epoch   1 |   411/  743 batches | lr 2.50 | ms/batch 21.08 | loss  6.79 | ppl   886.32
# | epoch   1 |   412/  743 batches | lr 2.50 | ms/batch 21.38 | loss  6.88 | ppl   973.56
# | epoch   1 |   413/  743 batches | lr 2.50 | ms/batch 21.75 | loss  6.88 | ppl   975.36
# | epoch   1 |   414/  743 batches | lr 2.50 | ms/batch 21.44 | loss  7.03 | ppl  1134.98
# | epoch   1 |   415/  743 batches | lr 2.50 | ms/batch 21.87 | loss  6.83 | ppl   925.46
# | epoch   1 |   416/  743 batches | lr 2.50 | ms/batch 21.66 | loss  6.97 | ppl  1066.94
# | epoch   1 |   417/  743 batches | lr 2.50 | ms/batch 21.79 | loss  6.84 | ppl   933.43
# | epoch   1 |   418/  743 batches | lr 2.50 | ms/batch 21.95 | loss  6.81 | ppl   903.26
# | epoch   1 |   419/  743 batches | lr 2.50 | ms/batch 21.57 | loss  6.64 | ppl   763.98
# | epoch   1 |   420/  743 batches | lr 2.50 | ms/batch 21.03 | loss  6.79 | ppl   887.57
# | epoch   1 |   421/  743 batches | lr 2.50 | ms/batch 21.03 | loss  6.75 | ppl   850.23
# | epoch   1 |   422/  743 batches | lr 2.50 | ms/batch 20.75 | loss  6.83 | ppl   924.83
# | epoch   1 |   423/  743 batches | lr 2.50 | ms/batch 20.82 | loss  6.86 | ppl   956.17
# | epoch   1 |   424/  743 batches | lr 2.50 | ms/batch 21.59 | loss  6.65 | ppl   769.32
# | epoch   1 |   425/  743 batches | lr 2.50 | ms/batch 22.59 | loss  6.63 | ppl   759.59
# | epoch   1 |   426/  743 batches | lr 2.50 | ms/batch 20.21 | loss  6.85 | ppl   940.10
# | epoch   1 |   427/  743 batches | lr 2.50 | ms/batch 20.86 | loss  6.77 | ppl   873.13
# | epoch   1 |   428/  743 batches | lr 2.50 | ms/batch 20.85 | loss  6.95 | ppl  1038.03
# | epoch   1 |   429/  743 batches | lr 2.50 | ms/batch 20.34 | loss  6.93 | ppl  1023.63
# | epoch   1 |   430/  743 batches | lr 2.50 | ms/batch 21.14 | loss  6.91 | ppl  1001.37
# | epoch   1 |   431/  743 batches | lr 2.50 | ms/batch 20.51 | loss  6.68 | ppl   794.67
# | epoch   1 |   432/  743 batches | lr 2.50 | ms/batch 21.31 | loss  6.81 | ppl   909.05
# | epoch   1 |   433/  743 batches | lr 2.50 | ms/batch 22.80 | loss  6.63 | ppl   756.98
# | epoch   1 |   434/  743 batches | lr 2.50 | ms/batch 23.19 | loss  6.87 | ppl   961.69
# | epoch   1 |   435/  743 batches | lr 2.50 | ms/batch 22.60 | loss  6.77 | ppl   869.23
# | epoch   1 |   436/  743 batches | lr 2.50 | ms/batch 21.51 | loss  6.98 | ppl  1077.42
# | epoch   1 |   437/  743 batches | lr 2.50 | ms/batch 21.31 | loss  6.84 | ppl   935.03
# | epoch   1 |   438/  743 batches | lr 2.50 | ms/batch 20.86 | loss  6.77 | ppl   872.77
# | epoch   1 |   439/  743 batches | lr 2.50 | ms/batch 21.61 | loss  6.78 | ppl   879.54
# | epoch   1 |   440/  743 batches | lr 2.50 | ms/batch 20.80 | loss  6.68 | ppl   793.54
# | epoch   1 |   441/  743 batches | lr 2.50 | ms/batch 20.72 | loss  6.72 | ppl   827.82
# | epoch   1 |   442/  743 batches | lr 2.50 | ms/batch 21.05 | loss  6.76 | ppl   859.31
# | epoch   1 |   443/  743 batches | lr 2.50 | ms/batch 20.83 | loss  6.83 | ppl   923.72
# | epoch   1 |   444/  743 batches | lr 2.50 | ms/batch 22.99 | loss  6.66 | ppl   780.52
# | epoch   1 |   445/  743 batches | lr 2.50 | ms/batch 24.78 | loss  6.78 | ppl   877.17
# | epoch   1 |   446/  743 batches | lr 2.50 | ms/batch 21.50 | loss  6.77 | ppl   872.65
# | epoch   1 |   447/  743 batches | lr 2.50 | ms/batch 21.15 | loss  6.84 | ppl   931.00
# | epoch   1 |   448/  743 batches | lr 2.50 | ms/batch 21.14 | loss  6.77 | ppl   870.47
# | epoch   1 |   449/  743 batches | lr 2.50 | ms/batch 20.97 | loss  6.81 | ppl   908.11
# | epoch   1 |   450/  743 batches | lr 2.50 | ms/batch 21.58 | loss  6.71 | ppl   818.31
# | epoch   1 |   451/  743 batches | lr 2.50 | ms/batch 20.81 | loss  6.74 | ppl   848.02
# | epoch   1 |   452/  743 batches | lr 2.50 | ms/batch 20.54 | loss  6.71 | ppl   823.47
# | epoch   1 |   453/  743 batches | lr 2.50 | ms/batch 20.93 | loss  6.91 | ppl  1003.11
# | epoch   1 |   454/  743 batches | lr 2.50 | ms/batch 22.88 | loss  7.07 | ppl  1181.54
# | epoch   1 |   455/  743 batches | lr 2.50 | ms/batch 23.49 | loss  6.99 | ppl  1080.65
# | epoch   1 |   456/  743 batches | lr 2.50 | ms/batch 21.85 | loss  7.14 | ppl  1262.50
# | epoch   1 |   457/  743 batches | lr 2.50 | ms/batch 21.19 | loss  7.52 | ppl  1851.55
# | epoch   1 |   458/  743 batches | lr 2.50 | ms/batch 21.92 | loss  7.33 | ppl  1524.60
# | epoch   1 |   459/  743 batches | lr 2.50 | ms/batch 21.20 | loss  7.16 | ppl  1292.58
# | epoch   1 |   460/  743 batches | lr 2.50 | ms/batch 21.69 | loss  7.11 | ppl  1230.06
# | epoch   1 |   461/  743 batches | lr 2.50 | ms/batch 22.08 | loss  7.16 | ppl  1284.50
# | epoch   1 |   462/  743 batches | lr 2.50 | ms/batch 21.66 | loss  6.93 | ppl  1020.38
# | epoch   1 |   463/  743 batches | lr 2.50 | ms/batch 23.11 | loss  6.86 | ppl   957.60
# | epoch   1 |   464/  743 batches | lr 2.50 | ms/batch 23.09 | loss  6.92 | ppl  1009.07
# | epoch   1 |   465/  743 batches | lr 2.50 | ms/batch 21.77 | loss  6.74 | ppl   844.97
# | epoch   1 |   466/  743 batches | lr 2.50 | ms/batch 22.42 | loss  6.82 | ppl   912.25
# | epoch   1 |   467/  743 batches | lr 2.50 | ms/batch 21.11 | loss  6.81 | ppl   911.00
# | epoch   1 |   468/  743 batches | lr 2.50 | ms/batch 21.79 | loss  6.78 | ppl   882.86
# | epoch   1 |   469/  743 batches | lr 2.50 | ms/batch 22.71 | loss  6.84 | ppl   931.37
# | epoch   1 |   470/  743 batches | lr 2.50 | ms/batch 21.87 | loss  6.75 | ppl   850.99
# | epoch   1 |   471/  743 batches | lr 2.50 | ms/batch 22.17 | loss  6.71 | ppl   817.18
# | epoch   1 |   472/  743 batches | lr 2.50 | ms/batch 21.74 | loss  6.72 | ppl   827.97
# | epoch   1 |   473/  743 batches | lr 2.50 | ms/batch 22.15 | loss  6.79 | ppl   887.70
# | epoch   1 |   474/  743 batches | lr 2.50 | ms/batch 23.43 | loss  6.71 | ppl   824.19
# | epoch   1 |   475/  743 batches | lr 2.50 | ms/batch 22.67 | loss  6.69 | ppl   804.03
# | epoch   1 |   476/  743 batches | lr 2.50 | ms/batch 22.08 | loss  6.64 | ppl   768.38
# | epoch   1 |   477/  743 batches | lr 2.50 | ms/batch 22.00 | loss  6.62 | ppl   751.31
# | epoch   1 |   478/  743 batches | lr 2.50 | ms/batch 22.44 | loss  6.76 | ppl   863.67
# | epoch   1 |   479/  743 batches | lr 2.50 | ms/batch 22.86 | loss  6.79 | ppl   886.58
# | epoch   1 |   480/  743 batches | lr 2.50 | ms/batch 21.45 | loss  6.94 | ppl  1037.22
# | epoch   1 |   481/  743 batches | lr 2.50 | ms/batch 22.37 | loss  6.78 | ppl   883.17
# | epoch   1 |   482/  743 batches | lr 2.50 | ms/batch 21.81 | loss  6.81 | ppl   904.69
# | epoch   1 |   483/  743 batches | lr 2.50 | ms/batch 23.03 | loss  6.83 | ppl   928.04
# | epoch   1 |   484/  743 batches | lr 2.50 | ms/batch 24.47 | loss  6.70 | ppl   808.68
# | epoch   1 |   485/  743 batches | lr 2.50 | ms/batch 22.36 | loss  6.63 | ppl   758.98
# | epoch   1 |   486/  743 batches | lr 2.50 | ms/batch 21.70 | loss  6.71 | ppl   820.04
# | epoch   1 |   487/  743 batches | lr 2.50 | ms/batch 22.85 | loss  6.75 | ppl   855.60
# | epoch   1 |   488/  743 batches | lr 2.50 | ms/batch 22.42 | loss  6.63 | ppl   755.42
# | epoch   1 |   489/  743 batches | lr 2.50 | ms/batch 22.32 | loss  6.87 | ppl   958.81
# | epoch   1 |   490/  743 batches | lr 2.50 | ms/batch 22.04 | loss  6.73 | ppl   837.94
# | epoch   1 |   491/  743 batches | lr 2.50 | ms/batch 22.24 | loss  6.76 | ppl   863.51
# | epoch   1 |   492/  743 batches | lr 2.50 | ms/batch 22.15 | loss  6.71 | ppl   820.99
# | epoch   1 |   493/  743 batches | lr 2.50 | ms/batch 22.27 | loss  6.79 | ppl   889.12
# | epoch   1 |   494/  743 batches | lr 2.50 | ms/batch 25.96 | loss  6.75 | ppl   851.92
# | epoch   1 |   495/  743 batches | lr 2.50 | ms/batch 22.33 | loss  6.56 | ppl   706.54
# | epoch   1 |   496/  743 batches | lr 2.50 | ms/batch 21.90 | loss  6.71 | ppl   816.81
# | epoch   1 |   497/  743 batches | lr 2.50 | ms/batch 22.56 | loss  6.67 | ppl   787.52
# | epoch   1 |   498/  743 batches | lr 2.50 | ms/batch 22.57 | loss  6.81 | ppl   910.07
# | epoch   1 |   499/  743 batches | lr 2.50 | ms/batch 21.66 | loss  6.76 | ppl   859.12
# | epoch   1 |   500/  743 batches | lr 2.50 | ms/batch 21.79 | loss  6.68 | ppl   798.00
# | epoch   1 |   501/  743 batches | lr 2.50 | ms/batch 21.74 | loss  6.74 | ppl   843.05
# | epoch   1 |   502/  743 batches | lr 2.50 | ms/batch 22.22 | loss  6.75 | ppl   852.00
# | epoch   1 |   503/  743 batches | lr 2.50 | ms/batch 21.45 | loss  6.65 | ppl   772.06
# | epoch   1 |   504/  743 batches | lr 2.50 | ms/batch 23.66 | loss  6.67 | ppl   789.14
# | epoch   1 |   505/  743 batches | lr 2.50 | ms/batch 23.75 | loss  6.71 | ppl   822.18
# | epoch   1 |   506/  743 batches | lr 2.50 | ms/batch 22.26 | loss  6.68 | ppl   799.95
# | epoch   1 |   507/  743 batches | lr 2.50 | ms/batch 21.70 | loss  6.78 | ppl   877.90
# | epoch   1 |   508/  743 batches | lr 2.50 | ms/batch 22.31 | loss  6.76 | ppl   861.12
# | epoch   1 |   509/  743 batches | lr 2.50 | ms/batch 21.61 | loss  6.73 | ppl   833.16
# | epoch   1 |   510/  743 batches | lr 2.50 | ms/batch 21.47 | loss  6.60 | ppl   734.02
# | epoch   1 |   511/  743 batches | lr 2.50 | ms/batch 21.11 | loss  6.99 | ppl  1087.97
# | epoch   1 |   512/  743 batches | lr 2.50 | ms/batch 21.40 | loss  7.11 | ppl  1221.02
# | epoch   1 |   513/  743 batches | lr 2.50 | ms/batch 21.97 | loss  7.21 | ppl  1358.23
# | epoch   1 |   514/  743 batches | lr 2.50 | ms/batch 21.33 | loss  7.06 | ppl  1169.11
# | epoch   1 |   515/  743 batches | lr 2.50 | ms/batch 21.94 | loss  7.10 | ppl  1212.22
# | epoch   1 |   516/  743 batches | lr 2.50 | ms/batch 21.41 | loss  6.90 | ppl   989.04
# | epoch   1 |   517/  743 batches | lr 2.50 | ms/batch 21.84 | loss  7.06 | ppl  1163.75
# | epoch   1 |   518/  743 batches | lr 2.50 | ms/batch 21.51 | loss  7.37 | ppl  1584.03
# | epoch   1 |   519/  743 batches | lr 2.50 | ms/batch 22.13 | loss  7.90 | ppl  2690.75
# | epoch   1 |   520/  743 batches | lr 2.50 | ms/batch 22.59 | loss  7.70 | ppl  2201.37
# | epoch   1 |   521/  743 batches | lr 2.50 | ms/batch 22.52 | loss  7.28 | ppl  1450.58
# | epoch   1 |   522/  743 batches | lr 2.50 | ms/batch 22.05 | loss  7.35 | ppl  1548.75
# | epoch   1 |   523/  743 batches | lr 2.50 | ms/batch 20.98 | loss  7.02 | ppl  1122.18
# | epoch   1 |   524/  743 batches | lr 2.50 | ms/batch 22.30 | loss  7.13 | ppl  1247.68
# | epoch   1 |   525/  743 batches | lr 2.50 | ms/batch 24.85 | loss  7.05 | ppl  1148.98
# | epoch   1 |   526/  743 batches | lr 2.50 | ms/batch 22.82 | loss  7.11 | ppl  1221.54
# | epoch   1 |   527/  743 batches | lr 2.50 | ms/batch 21.46 | loss  6.82 | ppl   914.57
# | epoch   1 |   528/  743 batches | lr 2.50 | ms/batch 21.81 | loss  6.90 | ppl   989.43
# | epoch   1 |   529/  743 batches | lr 2.50 | ms/batch 22.76 | loss  6.81 | ppl   904.82
# | epoch   1 |   530/  743 batches | lr 2.50 | ms/batch 22.35 | loss  6.66 | ppl   778.16
# | epoch   1 |   531/  743 batches | lr 2.50 | ms/batch 21.22 | loss  6.56 | ppl   704.24
# | epoch   1 |   532/  743 batches | lr 2.50 | ms/batch 22.53 | loss  6.62 | ppl   750.05
# | epoch   1 |   533/  743 batches | lr 2.50 | ms/batch 22.24 | loss  6.71 | ppl   824.67
# | epoch   1 |   534/  743 batches | lr 2.50 | ms/batch 25.03 | loss  6.75 | ppl   858.25
# | epoch   1 |   535/  743 batches | lr 2.50 | ms/batch 24.23 | loss  6.78 | ppl   881.68
# | epoch   1 |   536/  743 batches | lr 2.50 | ms/batch 22.90 | loss  6.81 | ppl   911.01
# | epoch   1 |   537/  743 batches | lr 2.50 | ms/batch 22.30 | loss  6.79 | ppl   890.08
# | epoch   1 |   538/  743 batches | lr 2.50 | ms/batch 22.33 | loss  6.65 | ppl   770.99
# ...
# | epoch  20 |   568/  743 batches | lr 0.62 | ms/batch 24.79 | loss  6.24 | ppl   513.85
# | epoch  20 |   569/  743 batches | lr 0.62 | ms/batch 24.40 | loss  5.77 | ppl   320.94
# | epoch  20 |   570/  743 batches | lr 0.62 | ms/batch 24.74 | loss  6.11 | ppl   448.77
# | epoch  20 |   571/  743 batches | lr 0.62 | ms/batch 24.25 | loss  6.11 | ppl   452.58
# | epoch  20 |   572/  743 batches | lr 0.62 | ms/batch 24.48 | loss  5.95 | ppl   383.94
# | epoch  20 |   573/  743 batches | lr 0.62 | ms/batch 30.84 | loss  6.03 | ppl   415.73
# | epoch  20 |   574/  743 batches | lr 0.62 | ms/batch 25.61 | loss  5.96 | ppl   387.26
# | epoch  20 |   575/  743 batches | lr 0.62 | ms/batch 24.02 | loss  6.02 | ppl   412.81
# | epoch  20 |   576/  743 batches | lr 0.62 | ms/batch 27.13 | loss  6.00 | ppl   404.47
# | epoch  20 |   577/  743 batches | lr 0.62 | ms/batch 26.58 | loss  5.91 | ppl   368.24
# | epoch  20 |   578/  743 batches | lr 0.62 | ms/batch 24.04 | loss  5.98 | ppl   395.83
# | epoch  20 |   579/  743 batches | lr 0.62 | ms/batch 24.14 | loss  5.98 | ppl   397.37
# | epoch  20 |   580/  743 batches | lr 0.62 | ms/batch 24.07 | loss  6.00 | ppl   401.73
# | epoch  20 |   581/  743 batches | lr 0.62 | ms/batch 23.89 | loss  6.13 | ppl   458.02
# | epoch  20 |   582/  743 batches | lr 0.62 | ms/batch 26.09 | loss  6.03 | ppl   416.34
# | epoch  20 |   583/  743 batches | lr 0.62 | ms/batch 23.26 | loss  5.96 | ppl   387.71
# | epoch  20 |   584/  743 batches | lr 0.62 | ms/batch 22.02 | loss  6.14 | ppl   464.29
# | epoch  20 |   585/  743 batches | lr 0.62 | ms/batch 22.86 | loss  5.96 | ppl   386.62
# | epoch  20 |   586/  743 batches | lr 0.62 | ms/batch 22.52 | loss  6.03 | ppl   417.09
# | epoch  20 |   587/  743 batches | lr 0.62 | ms/batch 22.31 | loss  6.12 | ppl   456.33
# | epoch  20 |   588/  743 batches | lr 0.62 | ms/batch 22.14 | loss  5.93 | ppl   375.32
# | epoch  20 |   589/  743 batches | lr 0.62 | ms/batch 22.16 | loss  5.96 | ppl   386.96
# | epoch  20 |   590/  743 batches | lr 0.62 | ms/batch 22.14 | loss  5.88 | ppl   356.22
# | epoch  20 |   591/  743 batches | lr 0.62 | ms/batch 22.28 | loss  5.92 | ppl   372.63
# | epoch  20 |   592/  743 batches | lr 0.62 | ms/batch 23.98 | loss  5.95 | ppl   382.83
# | epoch  20 |   593/  743 batches | lr 0.62 | ms/batch 23.44 | loss  5.94 | ppl   378.88
# | epoch  20 |   594/  743 batches | lr 0.62 | ms/batch 22.89 | loss  5.90 | ppl   364.03
# | epoch  20 |   595/  743 batches | lr 0.62 | ms/batch 22.74 | loss  5.92 | ppl   371.65
# | epoch  20 |   596/  743 batches | lr 0.62 | ms/batch 22.42 | loss  5.85 | ppl   348.83
# | epoch  20 |   597/  743 batches | lr 0.62 | ms/batch 22.27 | loss  5.85 | ppl   346.62
# | epoch  20 |   598/  743 batches | lr 0.62 | ms/batch 23.29 | loss  5.96 | ppl   386.42
# | epoch  20 |   599/  743 batches | lr 0.62 | ms/batch 22.16 | loss  6.08 | ppl   435.03
# | epoch  20 |   600/  743 batches | lr 0.62 | ms/batch 22.19 | loss  5.89 | ppl   359.89
# | epoch  20 |   601/  743 batches | lr 0.62 | ms/batch 22.45 | loss  6.03 | ppl   414.20
# | epoch  20 |   602/  743 batches | lr 0.62 | ms/batch 26.08 | loss  5.96 | ppl   388.01
# | epoch  20 |   603/  743 batches | lr 0.62 | ms/batch 23.58 | loss  5.95 | ppl   381.89
# | epoch  20 |   604/  743 batches | lr 0.62 | ms/batch 22.17 | loss  6.00 | ppl   402.62
# | epoch  20 |   605/  743 batches | lr 0.62 | ms/batch 21.99 | loss  6.10 | ppl   443.92
# | epoch  20 |   606/  743 batches | lr 0.62 | ms/batch 22.42 | loss  5.94 | ppl   379.47
# | epoch  20 |   607/  743 batches | lr 0.62 | ms/batch 24.17 | loss  5.99 | ppl   399.07
# | epoch  20 |   608/  743 batches | lr 0.62 | ms/batch 24.25 | loss  6.09 | ppl   439.31
# | epoch  20 |   609/  743 batches | lr 0.62 | ms/batch 24.36 | loss  5.94 | ppl   378.22
# | epoch  20 |   610/  743 batches | lr 0.62 | ms/batch 24.39 | loss  5.92 | ppl   373.28
# | epoch  20 |   611/  743 batches | lr 0.62 | ms/batch 24.30 | loss  6.06 | ppl   429.76
# | epoch  20 |   612/  743 batches | lr 0.62 | ms/batch 27.46 | loss  5.89 | ppl   360.46
# | epoch  20 |   613/  743 batches | lr 0.62 | ms/batch 24.27 | loss  5.99 | ppl   400.69
# | epoch  20 |   614/  743 batches | lr 0.62 | ms/batch 25.18 | loss  6.00 | ppl   405.40
# | epoch  20 |   615/  743 batches | lr 0.62 | ms/batch 26.07 | loss  5.95 | ppl   383.81
# | epoch  20 |   616/  743 batches | lr 0.62 | ms/batch 27.15 | loss  5.95 | ppl   383.35
# | epoch  20 |   617/  743 batches | lr 0.62 | ms/batch 26.66 | loss  6.05 | ppl   424.86
# | epoch  20 |   618/  743 batches | lr 0.62 | ms/batch 26.16 | loss  6.19 | ppl   488.53
# | epoch  20 |   619/  743 batches | lr 0.62 | ms/batch 27.16 | loss  5.89 | ppl   360.74
# | epoch  20 |   620/  743 batches | lr 0.62 | ms/batch 26.42 | loss  6.02 | ppl   411.85
# | epoch  20 |   621/  743 batches | lr 0.62 | ms/batch 24.11 | loss  6.08 | ppl   438.58
# | epoch  20 |   622/  743 batches | lr 0.62 | ms/batch 23.98 | loss  5.91 | ppl   370.28
# | epoch  20 |   623/  743 batches | lr 0.62 | ms/batch 24.38 | loss  6.04 | ppl   418.90
# | epoch  20 |   624/  743 batches | lr 0.62 | ms/batch 24.65 | loss  6.02 | ppl   411.14
# | epoch  20 |   625/  743 batches | lr 0.62 | ms/batch 22.57 | loss  5.87 | ppl   352.56
# | epoch  20 |   626/  743 batches | lr 0.62 | ms/batch 21.98 | loss  5.98 | ppl   396.60
# | epoch  20 |   627/  743 batches | lr 0.62 | ms/batch 22.86 | loss  5.96 | ppl   386.92
# | epoch  20 |   628/  743 batches | lr 0.62 | ms/batch 24.15 | loss  5.95 | ppl   385.12
# | epoch  20 |   629/  743 batches | lr 0.62 | ms/batch 23.34 | loss  5.90 | ppl   363.75
# | epoch  20 |   630/  743 batches | lr 0.62 | ms/batch 22.16 | loss  5.93 | ppl   377.79
# | epoch  20 |   631/  743 batches | lr 0.62 | ms/batch 22.16 | loss  6.09 | ppl   441.07
# | epoch  20 |   632/  743 batches | lr 0.62 | ms/batch 22.06 | loss  5.91 | ppl   368.45
# | epoch  20 |   633/  743 batches | lr 0.62 | ms/batch 22.30 | loss  6.00 | ppl   402.84
# | epoch  20 |   634/  743 batches | lr 0.62 | ms/batch 22.20 | loss  6.06 | ppl   426.54
# | epoch  20 |   635/  743 batches | lr 0.62 | ms/batch 22.07 | loss  5.97 | ppl   392.25
# | epoch  20 |   636/  743 batches | lr 0.62 | ms/batch 22.64 | loss  5.88 | ppl   359.20
# | epoch  20 |   637/  743 batches | lr 0.62 | ms/batch 32.76 | loss  5.91 | ppl   368.79
# | epoch  20 |   638/  743 batches | lr 0.62 | ms/batch 35.51 | loss  6.08 | ppl   438.60
# | epoch  20 |   639/  743 batches | lr 0.62 | ms/batch 34.02 | loss  5.83 | ppl   340.13
# | epoch  20 |   640/  743 batches | lr 0.62 | ms/batch 38.33 | loss  6.09 | ppl   441.58
# | epoch  20 |   641/  743 batches | lr 0.62 | ms/batch 32.30 | loss  5.97 | ppl   390.50
# | epoch  20 |   642/  743 batches | lr 0.62 | ms/batch 30.71 | loss  5.96 | ppl   385.84
# | epoch  20 |   643/  743 batches | lr 0.62 | ms/batch 40.88 | loss  5.92 | ppl   373.64
# | epoch  20 |   644/  743 batches | lr 0.62 | ms/batch 30.70 | loss  6.01 | ppl   408.44
# | epoch  20 |   645/  743 batches | lr 0.62 | ms/batch 28.80 | loss  6.02 | ppl   411.56
# | epoch  20 |   646/  743 batches | lr 0.62 | ms/batch 32.06 | loss  5.93 | ppl   376.85
# | epoch  20 |   647/  743 batches | lr 0.62 | ms/batch 33.21 | loss  5.87 | ppl   354.36
# | epoch  20 |   648/  743 batches | lr 0.62 | ms/batch 31.24 | loss  5.94 | ppl   381.19
# | epoch  20 |   649/  743 batches | lr 0.62 | ms/batch 26.98 | loss  6.04 | ppl   421.15
# | epoch  20 |   650/  743 batches | lr 0.62 | ms/batch 32.97 | loss  6.16 | ppl   471.92
# | epoch  20 |   651/  743 batches | lr 0.62 | ms/batch 36.09 | loss  6.02 | ppl   410.33
# | epoch  20 |   652/  743 batches | lr 0.62 | ms/batch 32.10 | loss  6.04 | ppl   421.12
# | epoch  20 |   653/  743 batches | lr 0.62 | ms/batch 27.34 | loss  5.97 | ppl   392.32
# | epoch  20 |   654/  743 batches | lr 0.62 | ms/batch 27.40 | loss  5.86 | ppl   350.83
# | epoch  20 |   655/  743 batches | lr 0.62 | ms/batch 26.52 | loss  5.96 | ppl   386.85
# | epoch  20 |   656/  743 batches | lr 0.62 | ms/batch 28.45 | loss  6.07 | ppl   434.24
# | epoch  20 |   657/  743 batches | lr 0.62 | ms/batch 36.59 | loss  5.89 | ppl   362.38
# | epoch  20 |   658/  743 batches | lr 0.62 | ms/batch 31.55 | loss  6.00 | ppl   403.13
# | epoch  20 |   659/  743 batches | lr 0.62 | ms/batch 27.30 | loss  6.02 | ppl   410.61
# | epoch  20 |   660/  743 batches | lr 0.62 | ms/batch 27.37 | loss  5.92 | ppl   373.68
# | epoch  20 |   661/  743 batches | lr 0.62 | ms/batch 27.32 | loss  5.87 | ppl   354.76
# | epoch  20 |   662/  743 batches | lr 0.62 | ms/batch 27.45 | loss  5.99 | ppl   400.35
# | epoch  20 |   663/  743 batches | lr 0.62 | ms/batch 38.10 | loss  5.96 | ppl   387.61
# | epoch  20 |   664/  743 batches | lr 0.62 | ms/batch 37.90 | loss  6.01 | ppl   409.02
# | epoch  20 |   665/  743 batches | lr 0.62 | ms/batch 35.21 | loss  5.96 | ppl   387.67
# | epoch  20 |   666/  743 batches | lr 0.62 | ms/batch 32.91 | loss  6.01 | ppl   409.27
# | epoch  20 |   667/  743 batches | lr 0.62 | ms/batch 27.04 | loss  5.88 | ppl   359.18
# | epoch  20 |   668/  743 batches | lr 0.62 | ms/batch 27.64 | loss  5.86 | ppl   350.06
# | epoch  20 |   669/  743 batches | lr 0.62 | ms/batch 28.72 | loss  6.04 | ppl   420.02
# | epoch  20 |   670/  743 batches | lr 0.62 | ms/batch 29.61 | loss  5.94 | ppl   379.39
# | epoch  20 |   671/  743 batches | lr 0.62 | ms/batch 41.77 | loss  5.91 | ppl   367.82
# | epoch  20 |   672/  743 batches | lr 0.62 | ms/batch 31.46 | loss  6.06 | ppl   429.33
# | epoch  20 |   673/  743 batches | lr 0.62 | ms/batch 26.63 | loss  5.84 | ppl   342.33
# | epoch  20 |   674/  743 batches | lr 0.62 | ms/batch 27.04 | loss  6.12 | ppl   454.46
# | epoch  20 |   675/  743 batches | lr 0.62 | ms/batch 33.30 | loss  6.02 | ppl   413.50
# | epoch  20 |   676/  743 batches | lr 0.62 | ms/batch 31.70 | loss  5.94 | ppl   381.75
# | epoch  20 |   677/  743 batches | lr 0.62 | ms/batch 29.51 | loss  5.95 | ppl   385.31
# | epoch  20 |   678/  743 batches | lr 0.62 | ms/batch 34.75 | loss  5.96 | ppl   387.08
# | epoch  20 |   679/  743 batches | lr 0.62 | ms/batch 32.29 | loss  5.94 | ppl   380.43
# | epoch  20 |   680/  743 batches | lr 0.62 | ms/batch 31.05 | loss  5.98 | ppl   395.48
# | epoch  20 |   681/  743 batches | lr 0.62 | ms/batch 31.96 | loss  5.85 | ppl   346.49
# | epoch  20 |   682/  743 batches | lr 0.62 | ms/batch 31.39 | loss  5.94 | ppl   379.05
# | epoch  20 |   683/  743 batches | lr 0.62 | ms/batch 32.49 | loss  6.02 | ppl   412.11
# | epoch  20 |   684/  743 batches | lr 0.62 | ms/batch 27.87 | loss  5.87 | ppl   355.97
# | epoch  20 |   685/  743 batches | lr 0.62 | ms/batch 27.81 | loss  5.98 | ppl   395.03
# | epoch  20 |   686/  743 batches | lr 0.62 | ms/batch 36.77 | loss  5.99 | ppl   399.36
# | epoch  20 |   687/  743 batches | lr 0.62 | ms/batch 32.81 | loss  5.94 | ppl   379.48
# | epoch  20 |   688/  743 batches | lr 0.62 | ms/batch 32.47 | loss  6.05 | ppl   423.90
# | epoch  20 |   689/  743 batches | lr 0.62 | ms/batch 27.19 | loss  6.05 | ppl   424.42
# | epoch  20 |   690/  743 batches | lr 0.62 | ms/batch 28.54 | loss  6.02 | ppl   409.80
# | epoch  20 |   691/  743 batches | lr 0.62 | ms/batch 26.62 | loss  5.89 | ppl   359.67
# | epoch  20 |   692/  743 batches | lr 0.62 | ms/batch 27.09 | loss  6.10 | ppl   447.91
# | epoch  20 |   693/  743 batches | lr 0.62 | ms/batch 31.83 | loss  6.02 | ppl   410.26
# | epoch  20 |   694/  743 batches | lr 0.62 | ms/batch 31.16 | loss  5.98 | ppl   395.66
# | epoch  20 |   695/  743 batches | lr 0.62 | ms/batch 30.53 | loss  6.01 | ppl   406.40
# | epoch  20 |   696/  743 batches | lr 0.62 | ms/batch 28.22 | loss  5.97 | ppl   392.52
# | epoch  20 |   697/  743 batches | lr 0.62 | ms/batch 26.77 | loss  6.03 | ppl   416.16
# | epoch  20 |   698/  743 batches | lr 0.62 | ms/batch 28.00 | loss  5.95 | ppl   382.90
# | epoch  20 |   699/  743 batches | lr 0.62 | ms/batch 34.82 | loss  5.88 | ppl   358.13
# | epoch  20 |   700/  743 batches | lr 0.62 | ms/batch 36.96 | loss  5.90 | ppl   366.22
# | epoch  20 |   701/  743 batches | lr 0.62 | ms/batch 27.66 | loss  5.95 | ppl   383.69
# | epoch  20 |   702/  743 batches | lr 0.62 | ms/batch 27.86 | loss  5.98 | ppl   394.32
# | epoch  20 |   703/  743 batches | lr 0.62 | ms/batch 29.54 | loss  5.94 | ppl   378.80
# | epoch  20 |   704/  743 batches | lr 0.62 | ms/batch 27.92 | loss  5.99 | ppl   400.78
# | epoch  20 |   705/  743 batches | lr 0.62 | ms/batch 27.92 | loss  6.02 | ppl   409.77
# | epoch  20 |   706/  743 batches | lr 0.62 | ms/batch 35.29 | loss  5.89 | ppl   362.73
# | epoch  20 |   707/  743 batches | lr 0.62 | ms/batch 36.18 | loss  5.95 | ppl   385.58
# | epoch  20 |   708/  743 batches | lr 0.62 | ms/batch 28.86 | loss  6.09 | ppl   441.42
# | epoch  20 |   709/  743 batches | lr 0.62 | ms/batch 32.04 | loss  5.97 | ppl   390.20
# | epoch  20 |   710/  743 batches | lr 0.62 | ms/batch 31.86 | loss  5.88 | ppl   356.54
# | epoch  20 |   711/  743 batches | lr 0.62 | ms/batch 28.17 | loss  6.01 | ppl   407.38
# | epoch  20 |   712/  743 batches | lr 0.62 | ms/batch 33.22 | loss  5.94 | ppl   379.01
# | epoch  20 |   713/  743 batches | lr 0.62 | ms/batch 38.19 | loss  5.87 | ppl   354.46
# | epoch  20 |   714/  743 batches | lr 0.62 | ms/batch 32.61 | loss  5.91 | ppl   369.61
# | epoch  20 |   715/  743 batches | lr 0.62 | ms/batch 26.77 | loss  6.00 | ppl   403.01
# | epoch  20 |   716/  743 batches | lr 0.62 | ms/batch 26.66 | loss  6.00 | ppl   403.36
# | epoch  20 |   717/  743 batches | lr 0.62 | ms/batch 26.30 | loss  6.02 | ppl   410.91
# | epoch  20 |   718/  743 batches | lr 0.62 | ms/batch 25.80 | loss  6.10 | ppl   445.69
# | epoch  20 |   719/  743 batches | lr 0.62 | ms/batch 26.07 | loss  6.05 | ppl   425.58
# | epoch  20 |   720/  743 batches | lr 0.62 | ms/batch 26.17 | loss  5.92 | ppl   370.85
# | epoch  20 |   721/  743 batches | lr 0.62 | ms/batch 27.91 | loss  6.10 | ppl   447.46
# | epoch  20 |   722/  743 batches | lr 0.62 | ms/batch 31.50 | loss  6.15 | ppl   468.22
# | epoch  20 |   723/  743 batches | lr 0.62 | ms/batch 27.38 | loss  6.10 | ppl   445.50
# | epoch  20 |   724/  743 batches | lr 0.62 | ms/batch 27.51 | loss  6.05 | ppl   423.48
# | epoch  20 |   725/  743 batches | lr 0.62 | ms/batch 26.84 | loss  6.06 | ppl   428.95
# | epoch  20 |   726/  743 batches | lr 0.62 | ms/batch 27.00 | loss  6.10 | ppl   443.99
# | epoch  20 |   727/  743 batches | lr 0.62 | ms/batch 26.79 | loss  6.12 | ppl   452.74
# | epoch  20 |   728/  743 batches | lr 0.62 | ms/batch 27.42 | loss  6.00 | ppl   404.73
# | epoch  20 |   729/  743 batches | lr 0.62 | ms/batch 31.69 | loss  5.98 | ppl   397.16
# | epoch  20 |   730/  743 batches | lr 0.62 | ms/batch 32.21 | loss  5.91 | ppl   369.24
# | epoch  20 |   731/  743 batches | lr 0.62 | ms/batch 26.72 | loss  5.99 | ppl   399.98
# | epoch  20 |   732/  743 batches | lr 0.62 | ms/batch 26.56 | loss  6.05 | ppl   424.35
# | epoch  20 |   733/  743 batches | lr 0.62 | ms/batch 26.57 | loss  6.04 | ppl   419.87
# | epoch  20 |   734/  743 batches | lr 0.62 | ms/batch 28.41 | loss  6.02 | ppl   411.25
# | epoch  20 |   735/  743 batches | lr 0.62 | ms/batch 26.71 | loss  5.96 | ppl   388.27
# | epoch  20 |   736/  743 batches | lr 0.62 | ms/batch 28.03 | loss  5.89 | ppl   359.62
# | epoch  20 |   737/  743 batches | lr 0.62 | ms/batch 34.35 | loss  5.98 | ppl   396.12
# | epoch  20 |   738/  743 batches | lr 0.62 | ms/batch 30.18 | loss  6.14 | ppl   465.25
# | epoch  20 |   739/  743 batches | lr 0.62 | ms/batch 26.69 | loss  6.09 | ppl   440.14
# | epoch  20 |   740/  743 batches | lr 0.62 | ms/batch 26.81 | loss  5.90 | ppl   366.63
# | epoch  20 |   741/  743 batches | lr 0.62 | ms/batch 34.82 | loss  5.96 | ppl   386.15
# | epoch  20 |   742/  743 batches | lr 0.62 | ms/batch 31.61 | loss  6.06 | ppl   426.69
# | epoch  20 |   743/  743 batches | lr 0.62 | ms/batch 23.74 | loss  5.92 | ppl   372.41
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 22.37s | valid loss  6.01 | valid ppl   405.93
# -----------------------------------------------------------------------------------------

# %%
corpus

# %%
corpus.train.shape
# Out:
# torch.Size([929589])

# %%
corpus.test.shape
# Out:
# torch.Size([82430])

# %%
corpus.valid.shape
# Out:
# torch.Size([73760])

# %%
len(corpus.dictionary.idx2word)
# Out:
# 10000

# %%
corpus.dictionary.word2idx['<unk>']
# Out:
# 26

# %%
corpus.dictionary.word2idx['<eos>']
# Out:
# 24

# %%
corpus.
# Out:
#   Cell In[18], line 1
#     corpus.
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# There is a lot more that you can do with outputs (such as including interactive outputs)
# with your book. For more information about this, see [the Jupyter Book documentation](https://jupyterbook.org)

# %%
from mymodel import MyElmanNetwork
import torch.optim as optim

# Example usage
vocab_size = 10000
embedding_dim = 100
input_size = embedding_dim
hidden_size = 20
output_size = 5
sequence_length = 6
batch_size = 3
num_epochs = 10
learning_rate = 0.001

# Create an instance of the Elman network
elman_net = MyElmanNetwork(input_size, hidden_size, output_size, vocab_size, embedding_dim)

# Generate some random input sequence and corresponding target labels
input_sequence = torch.randint(0, vocab_size, (batch_size, sequence_length))
target_labels = torch.randint(0, output_size, (batch_size, sequence_length))

# Define the loss function and the optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(elman_net.parameters(), lr=learning_rate)

# Training loop
for epoch in range(num_epochs):
    # Zero the gradients
    optimizer.zero_grad()

    # Forward pass
    outputs = elman_net(input_sequence)

    # Reshape outputs and target labels for loss calculation
    outputs = outputs.view(-1, output_size)
    target_labels = target_labels.view(-1)

    # Calculate the loss
    loss = loss_function(outputs, target_labels)

    # Backward pass and optimization step
    loss.backward()
    optimizer.step()

    # Print the loss for each epoch
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {loss.item()}")

# Print the final outputs
final_outputs = elman_net(input_sequence)
print(final_outputs)
# Out:
# Epoch 1/10, Loss: 1.6084262132644653
# Epoch 2/10, Loss: 1.5708050727844238
# Epoch 3/10, Loss: 1.5337529182434082
# Epoch 4/10, Loss: 1.4973175525665283
# Epoch 5/10, Loss: 1.4615721702575684
# Epoch 6/10, Loss: 1.4265872240066528
# Epoch 7/10, Loss: 1.3924317359924316
# Epoch 8/10, Loss: 1.3591649532318115
# Epoch 9/10, Loss: 1.326827883720398
# Epoch 10/10, Loss: 1.2954357862472534
# tensor([[[-0.4557,  0.3464,  0.6389,  0.3665, -0.7939],
#          [ 0.1077,  0.0440,  0.5277,  0.1991,  0.1102],
#          [-0.2033,  0.5700, -0.0068,  0.3846,  0.2028],
#          [ 0.2616, -0.4129,  0.1387,  0.0085,  0.7012],
#          [-0.4419,  0.3845,  0.0186,  0.4997, -0.4066],
#          [-0.2927,  0.0781,  0.9332,  0.6109, -0.3657]],
#
#         [[-0.0044, -0.1858,  0.0045,  0.6286,  0.2181],
#          [ 0.0687,  0.1818, -0.2695,  0.2359, -0.0188],
#          [-0.5020, -0.2445,  0.2477,  0.6203, -0.5808],
#          [-0.6771, -0.3951,  0.8126,  0.3976, -0.4112],
#          [-0.0098,  0.5429, -0.4774,  0.2871, -0.4462],
#          [ 0.4624,  0.8026,  0.7343,  0.1030, -0.6451]],
#
#         [[-0.3740,  0.0705, -0.1563,  0.0804, -0.0381],
#          [-0.1617,  0.3665, -0.5421,  0.6709,  0.4509],
#          [-0.4599,  0.6289, -0.0542,  0.0139, -0.1711],
#          [-0.2436, -0.3118,  0.4686,  0.5402, -0.3701],
#          [-0.3192,  0.3692, -0.5879,  0.0656,  0.2069],
#          [-0.2186,  0.8157,  0.6603,  0.1226, -0.7173]]],
#        grad_fn=<AddBackward0>)
